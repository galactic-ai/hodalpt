# %% [markdown]
# ## parameter reduction tests

# %%
import numpy as np 
import matplotlib.pyplot as plt
from hodalpt.sims import alpt as CS
from hodalpt.sims import quijote as Q
from hodalpt import stats
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from hodalpt.sims import alpt as CS
#       4 from hodalpt.sims import quijote as Q
#       5 from hodalpt import stats
#
# File ~/CosmicSim2025/hodalpt/src/hodalpt/sims/alpt.py:19
#      16 from numba import njit, prange
#      18 from . import cwc as C
# ---> 19 from . import quijote as Q
#      22 def CSbox_galaxy(theta_gal, theta_rsd, dm_dir, Ngrid=256, Lbox=1000.,
#      23                  zsnap=0.5, lambdath_tweb=0.0, lambdath_twebdelta = 0.0,
#      24                  seed=123456, silent=True):
#      25     ''' construct CosmicSignal galaxy mock given DM box. Applies the bias model
#      26     in hodalpt.sims.cwc to specified ALPT DM output
#      27
#    (...)     59         Ngal x 3 array specifying the x, y, z position of galaxies.
#      60     '''
#
# File ~/CosmicSim2025/hodalpt/src/hodalpt/sims/quijote.py:26
#      23 import hdf5plugin
#      24 import numpy as np
# ---> 26 import nbodykit.lab as NBlab
#      27 from simbig import galaxies as G
#      30 quijote_zsnap_dict = {0.: 4, 0.5: 3, 1.:2, 2.: 1, 3.: 0}
#
# File ~/CosmicSim2025/nbodykit/nbodykit/lab.py:8
#       5 import numpy
#       7 # sources
# ----> 8 from nbodykit.source.catalog import *
#       9 from nbodykit.source.mesh import *
#      11 # algorithms
#
# File ~/CosmicSim2025/nbodykit/nbodykit/source/catalog/__init__.py:2
#       1 # catalogs for different file types
# ----> 2 from .file import CSVCatalog
#       3 from .file import BinaryCatalog
#       4 from .file import BigFileCatalog
#
# File ~/CosmicSim2025/nbodykit/nbodykit/source/catalog/file.py:1
# ----> 1 from nbodykit.base.catalog import CatalogSource
#       2 from nbodykit.io.stack import FileStack
#       3 from nbodykit import CurrentMPIComm
#
# File ~/CosmicSim2025/nbodykit/nbodykit/base/catalog.py:2
#       1 from nbodykit.transform import ConstantArray
# ----> 2 from nbodykit import _global_options, CurrentMPIComm
#       4 from six import string_types, add_metaclass
#       5 import numpy
#
# ImportError: cannot import name '_global_options' from 'nbodykit' (unknown location)

# %%
theta_hod
